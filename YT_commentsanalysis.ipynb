# %%
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd

API_KEY = 'AIzaSyAE3LhQlmckC7boqdjcPjZmTfyrw9TS3ZA'
CHANNEL_ID = 'UC0zYzxRCvUD5p1XWwE00Zzw'

def get_youtube_service():
    return googleapiclient.discovery.build('youtube', 'v3', developerKey=API_KEY)

def get_channel_videos(youtube, channel_id):
    videos = []
    request = youtube.search().list(
        part='id',
        channelId=channel_id,
        maxResults=50,
        type='video'
    )

    while request is not None:
        response = request.execute()
        videos += response['items']
        request = youtube.search().list_next(request, response)

    return videos

def get_video_metadata(youtube, video_id):
    request = youtube.videos().list(
        part='snippet,contentDetails,statistics',
        id=video_id
    )
    response = request.execute()

    try:
        response = response['items'][0]
        data = {
            'ID': response['id'],
            'TITLE': response['snippet']['title'],
            'DESCRIPTION': response['snippet']['description'],
            'PUBLISHED_AT': response['snippet']['publishedAt'],
            'CATEGORY_ID': response['snippet']['categoryId'],
            'DURATION': response['contentDetails']['duration'],
            'CAPTION': response['contentDetails']['caption'],
            'LIKE_COUNT': response['statistics']['likeCount'],
            'COMMENT_COUNT': response['statistics']['commentCount'],
            'VIEW_COUNT': response['statistics']['viewCount'],
        }
        return data
    except Exception as e:
        print(f"Error: {e}")
        return None

def get_video_comments(youtube, video_id):
    next_page_token = None
    comments = []

    try:
        while True:
            comment_thread = youtube.commentThreads().list(
                part="snippet,replies",
                order="relevance",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
            ).execute()

            for item in comment_thread['items']:
                snippet = item['snippet']['topLevelComment']['snippet']
                comment = {
                    'REPLY_COUNT': item['snippet']['totalReplyCount'],
                    'AUTHOR': snippet['authorDisplayName'],
                    'TEXT': snippet['textDisplay'],
                    'LIKE_COUNT': snippet['likeCount'],
                    'PUBLISHED_AT': snippet['publishedAt'],
                    'VIDEO_ID': video_id,
                }
                comments.append(comment)

                if 'replies' in item:
                    for reply_item in item['replies']['comments']:
                        reply_snippet = reply_item['snippet']
                        reply = {
                            'REPLY_COUNT': 0,
                            'AUTHOR': reply_snippet['authorDisplayName'],
                            'TEXT': reply_snippet['textDisplay'],
                            'LIKE_COUNT': reply_snippet['likeCount'],
                            'PUBLISHED_AT': reply_snippet['publishedAt'],
                            'VIDEO_ID': video_id,
                        }
                        comments.append(reply)

            next_page_token = comment_thread.get("nextPageToken")
            if not next_page_token:
                break
    except Exception as e:
        print(f"Error fetching comments: {e}")
        return []

    return comments

def main():
    youtube = get_youtube_service()

    videos = get_channel_videos(youtube, CHANNEL_ID)
    video_ids = [video['id']['videoId'] for video in videos]

    all_videos_data = []
    all_comments_data = []

    for i, video_id in enumerate(video_ids, 1):
        print(f"Processing video {i}/{len(video_ids)}: {video_id}")

        video_metadata = get_video_metadata(youtube, video_id)
        if video_metadata:
            all_videos_data.append(video_metadata)

        comments = get_video_comments(youtube, video_id)
        all_comments_data.extend(comments)

    videos_df = pd.DataFrame(all_videos_data)
    videos_df.to_csv('videos.csv', index=False)

    comments_df = pd.DataFrame(all_comments_data)
    comments_df.to_csv('comments.csv', index=False)

    print(f"\nDone! Saved {len(all_videos_data)} videos and {len(all_comments_data)} comments.")

if __name__ == '__main__':
    main()
# Out:
# Processing video 1/228: 3t5-YzRuduw
# Processing video 2/228: GE1hRKeQQDE
# Processing video 3/228: uW02XBOhsDk
# Processing video 4/228: KeYHxf0Bnc8
# Processing video 5/228: 3xcLLI9qU3U
# Processing video 6/228: ioVUC5ZSnLk
# Processing video 7/228: 7-O1ViYpXV8
# Processing video 8/228: cNAAdEEYZF8
# Processing video 9/228: C9HSMFW6jJY
# Processing video 10/228: dczISLNK3FI
# Processing video 11/228: biOL0_HVWek
# Processing video 12/228: C4mZGuluzus
# Processing video 13/228: VKCEUSlTFRI
# Processing video 14/228: nfIF45yiLME
# Processing video 15/228: w-Yu8XuBk8g
# Processing video 16/228: ueCRrtz201k
# Processing video 17/228: j056PyJcWZA
# Processing video 18/228: Ll4NrKXEcL8
# Processing video 19/228: BlL0UmRpEuo
# Processing video 20/228: KrYCISP2A6o
# Processing video 21/228: fRO2aQLYTDI
# Processing video 22/228: dkTtv3UB9m4
# Processing video 23/228: o5siMJVKSKo
# Processing video 24/228: 0lhmEFmXoM0
# Processing video 25/228: yBUgPaqU7ck
# Processing video 26/228: p5UlQlp_ef0
# Processing video 27/228: yigba9-gMfU
# Processing video 28/228: -AYPzbSIQbY
# Processing video 29/228: tjlsz1BRa0A
# Processing video 30/228: uWyqnNN2-G8
# Processing video 31/228: FJLOeAYRQYI
# Processing video 32/228: 3whr0IziOv0
# Processing video 33/228: K4NpBqx32yg
# Processing video 34/228: _jLVRBLBAOc
# Processing video 35/228: y9g6SmErmiU
# Processing video 36/228: mBAvnHfBjdE
# Processing video 37/228: X32rLkpBBMg
# Processing video 38/228: nEQtm0Rhw_4
# Processing video 39/228: q73vOy0tYP8
# Processing video 40/228: rAD7D_RiwIs
# Processing video 41/228: LSBOPxap5eE
# Processing video 42/228: oLrppKS8J_U
# Processing video 43/228: op--cVCR2-k
# Processing video 44/228: OuspyNbVFU8
# Processing video 45/228: 8b1PDihQ1YY
# Processing video 46/228: 7o79-sGOIW4
# Processing video 47/228: 4me9-9DFdFY
# Processing video 48/228: GVolooU1CVU
# Processing video 49/228: IxaIjUj6LvA
# Processing video 50/228: WPiSEkiQ2yo
# Processing video 51/228: GTTi-F8jb4E
# Processing video 52/228: AowmbHdgmns
# Processing video 53/228: yl_RfOZGIS4
# Processing video 54/228: T4dHy4R-eSo
# Processing video 55/228: TsndI6VON7E
# Processing video 56/228: -aqmtd2kPck
# Processing video 57/228: 51jP_x34s68
# Processing video 58/228: wowuoBruLCE
# Processing video 59/228: Q0nw0eIao4s
# Processing video 60/228: qlE0P-bZ_uU
# Processing video 61/228: RiHvxo42DPM
# Processing video 62/228: i7rEzPlv77Q
# Processing video 63/228: O5LtOLle9js
# Processing video 64/228: GavjvEf9FMc
# Processing video 65/228: 4OWRBwBVO5E
# Processing video 66/228: 8KWBWBpFgqc
# Processing video 67/228: JK33BprDzak
# Processing video 68/228: Zgis_obkKIw
# Processing video 69/228: JpK_VpAE6Dw
# Processing video 70/228: eF5TTYuL058
# Processing video 71/228: N9t4ZBZAR4k
# Processing video 72/228: gIByyWbqEmE
# Processing video 73/228: SpwuTNknDX0
# Processing video 74/228: lNdYi0N9704
# Processing video 75/228: kejdLHhVvv4
# Processing video 76/228: iIFRC32wMaU
# Processing video 77/228: n8WjvUdFzM8
# Processing video 78/228: qZCi2Q0iL2U
# Processing video 79/228: WWpojHtb7ZU
# Processing video 80/228: 7QTmP-_rsTw
# Processing video 81/228: WwntM9t_wd8
# Processing video 82/228: TbQJ6NN37TU
# Processing video 83/228: Q4rBetDo6oc
# Processing video 84/228: ydpP6oTZXhc
# Processing video 85/228: LiwtvHineIE
# Processing video 86/228: n8joz8lYUvM
# Processing video 87/228: MRml5ilvABc
# Processing video 88/228: 9NpYNuklvMg
# Processing video 89/228: Ds0FEa-kXlA
# Processing video 90/228: v0kwpL-i5t0
# Processing video 91/228: J5BN-iBzVa4
# Processing video 92/228: rm2vDOzBUqg
# Processing video 93/228: FViyz_ZO2FY
# Processing video 94/228: _-hZFsbeX0o
# Processing video 95/228: kkwbfMhYm_Y
# Processing video 96/228: a3k1kF-KtRg
# Processing video 97/228: 1jWBsX4u6TE
# Processing video 98/228: JYEq0M-ty1s
# Processing video 99/228: dqXn_aByh-U
# Processing video 100/228: CHaLk57I_MU
# Processing video 101/228: x6ROsuK_cm4
# Processing video 102/228: NABfTopKyAg
# Processing video 103/228: eU5tqNWsG4I
# Processing video 104/228: eGmn2gHMryI
# Processing video 105/228: CfPLJe40RyU
# Error: 'likeCount'
# Processing video 106/228: PnI4NIJsL3k
# Processing video 107/228: 4G7hNhYOeNY
# Processing video 108/228: FwSDselYmxo
# Processing video 109/228: BZdn5rZUd0o
# Processing video 110/228: 8eh51uhX3pg
# Processing video 111/228: _-KL1sCgGNQ
# Processing video 112/228: EdA2YoUjZ1A
# Processing video 113/228: 3ja7qI7aleo
# Processing video 114/228: IpEJSHi3hao
# Processing video 115/228: Khi6rqtVkpA
# Processing video 116/228: 9XgLfhzM-j8
# Processing video 117/228: VUJUmeLzQMk
# Processing video 118/228: 5H8HFcLYEg0
# Processing video 119/228: Dk6fy8MClhs
# Processing video 120/228: BMqvt_-FK_Y
# Processing video 121/228: UkN2bq_jc4Y
# Processing video 122/228: Km7PE7u5Y7I
# Processing video 123/228: p66KleQZtkA
# Processing video 124/228: qK2xu84VvyM
# Processing video 125/228: UW0L8ptFgI0
# Processing video 126/228: nBQnTIR6Xjc
# Processing video 127/228: Nv46r3cCcac
# Processing video 128/228: r8MeotdUnVw
# Processing video 129/228: skR76ZrEf_8
# Processing video 130/228: uW8Q6PmEZ6I
# Processing video 131/228: nePiwGV8UWQ
# Processing video 132/228: KSwNerqYwf4
# Processing video 133/228: uPktKML336Y
# Processing video 134/228: D079RAM8CJc
# Processing video 135/228: EgG1ZGVOtVM
# Processing video 136/228: jjQiZt1eAMY
# Processing video 137/228: DKe16bpiTeM
# Processing video 138/228: x-3ZF8jSEAc
# Processing video 139/228: VUGmB4JNhp4
# Processing video 140/228: 31oicAVWDyo
# Processing video 141/228: Abep7zUaxPM
# Processing video 142/228: Z2-eOdwJSTg
# Processing video 143/228: 1zuDD7V7y2Q
# Processing video 144/228: 9fJELcdihqQ
# Processing video 145/228: a2cmvrlw3-o
# Processing video 146/228: Sd1z9wZ4-G8
# Processing video 147/228: ELIxuAE__-4
# Processing video 148/228: s573fntmL-c
# Processing video 149/228: 8XWhJO9kJGM
# Processing video 150/228: kwVqrFULKN0
# Processing video 151/228: 9sFaMbtAdss
# Processing video 152/228: k9x2UlCeJnw
# Processing video 153/228: O6xYJbmho3Y
# Processing video 154/228: dhruTpVN2-E
# Processing video 155/228: jSv_h2-yZn4
# Processing video 156/228: AzhummRPSzk
# Processing video 157/228: d700VQpodEI
# Processing video 158/228: X583tmW2zks
# Processing video 159/228: tT49nGr85Po
# Processing video 160/228: VJJsQIz4i2I
# Processing video 161/228: dm92QDQJAX0
# Processing video 162/228: jYPxEkUPeu8
# Processing video 163/228: 1hJ0R8t5sYU
# Processing video 164/228: yZ-MQQioya8
# Processing video 165/228: gIQ20zp8VsU
# Processing video 166/228: MwgGK8czlT8
# Processing video 167/228: eZvUgQgKjMc
# Processing video 168/228: vgPIFE5WWMU
# Processing video 169/228: NFbh0_GGOyo
# Processing video 170/228: alHRKTCAOR8
# Processing video 171/228: y8eGRnb8o0Y
# Processing video 172/228: 2L1DuUgyC14
# Processing video 173/228: 4ZD0jT_YwDQ
# Processing video 174/228: dbDZ0Z4UlPM
# Processing video 175/228: 94APPA90l8M
# Processing video 176/228: ZO9VXMZAlio
# Processing video 177/228: z3XpiP3vWe4
# Processing video 178/228: xMzlS7Vnd2U
# Processing video 179/228: zRofkCtlE8M
# Processing video 180/228: c6Oqd6OYdQA
# Processing video 181/228: j_4N26kxXx8
# Processing video 182/228: RzVdukWlP9s
# Processing video 183/228: UcUUvAvEKFo
# Processing video 184/228: 4kdlVsfxhaU
# Processing video 185/228: y8nMqIiKnns
# Processing video 186/228: 1wFK1zN5lPI
# Processing video 187/228: _f8I2vcy9Sw
# Processing video 188/228: EGw5I-F8fT0
# Processing video 189/228: nrooGtUao6c
# Processing video 190/228: JIWsPbTw5-o
# Processing video 191/228: OWd8KtaB0o8
# Processing video 192/228: dz8JMOsJhhg
# Processing video 193/228: uvkEXNM6OTo
# Processing video 194/228: eM85KAakRQ8
# Processing video 195/228: zPEi1CtvCeM
# Processing video 196/228: H6z7TkGdPak
# Processing video 197/228: 0GEuV92KW08
# Processing video 198/228: F0VIE-YuQKM
# Processing video 199/228: SU-QxE36fy4
# Processing video 200/228: yc6dRFT5vsI
# Processing video 201/228: 3Fq-_ydWnK4
# Processing video 202/228: HtMDkNP7i9M
# Processing video 203/228: 86DxarMbtcQ
# Processing video 204/228: Rl2kN2qSxx8
# Processing video 205/228: b5GG9cI488A
# Processing video 206/228: skJjT7y_Zcg
# Processing video 207/228: 935r7UFf2LQ
# Processing video 208/228: QkhFH760AFQ
# Processing video 209/228: sC1BCCCa8WY
# Processing video 210/228: B98f9HHa5xA
# Processing video 211/228: vAviGEKnRTg
# Processing video 212/228: 5eTVQHFMekk
# Processing video 213/228: KVLTR3rcBxw
# Processing video 214/228: mmTL_Ie6j1k
# Processing video 215/228: mwXb7MoRyLk
# Processing video 216/228: GO67DB4ac18
# Processing video 217/228: unkA_1oiOB0
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Processing video 218/228: Jt2i2CEzBSo
# Error: 'commentCount'
# Error fetching comments: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&order=relevance&videoId=Jt2i2CEzBSo&maxResults=100&key=AIzaSyAE3LhQlmckC7boqdjcPjZmTfyrw9TS3ZA&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Processing video 219/228: V8efNQoLa0o
# Processing video 220/228: rx5rDMPSjnI
# Processing video 221/228: n6qWskrXS4w
# Processing video 222/228: kWrtyD5zkZk
# Processing video 223/228: xIFbIKUxaHw
# Processing video 224/228: Lm6z9DPOsuE
# Processing video 225/228: 0nK8cs8Nd-k
# Processing video 226/228: jxh1rcNAlVY
# Processing video 227/228: tQ76IYjNjlE
# Processing video 228/228: msZv_ccF-Jc
#
# Done! Saved 226 videos and 93210 comments.

# %%
import re
from html import unescape
import string
from textblob import TextBlob
import pandas as pd

def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = unescape(text)
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def iso8601_to_minutes(duration) -> int:
    # Check if duration is already a number or not a string
    if isinstance(duration, (int, float)):
        return int(duration)

    # Convert to string if it isn't already
    duration = str(duration)

    hours = re.search(r'(\d+)H', duration)
    minutes = re.search(r'(\d+)M', duration)
    seconds = re.search(r'(\d+)S', duration)

    hours = int(hours.group(1)) if hours else 0
    minutes = int(minutes.group(1)) if minutes else 0
    seconds = int(seconds.group(1)) if seconds else 0

    total_minutes = hours * 60 + minutes + (seconds / 60)
    return int(total_minutes)

def get_sentiment_score(text):
    # Handle non-string values
    if not isinstance(text, str):
        return 0.0
    blob = TextBlob(text)
    return blob.sentiment.polarity

def main():
    comments_df = pd.read_csv('/content/comments_preprocessed.csv', encoding='utf-8')
    videos_df = pd.read_csv('/content/videos_preprocessed.csv', encoding='utf-8')

    comments_df.dropna(inplace=True)
    comments_df['TEXT'] = comments_df['TEXT'].apply(clean_text)
    comments_df['SCORE'] = comments_df['TEXT'].apply(get_sentiment_score)

    videos_df['DURATION'] = videos_df['DURATION'].apply(iso8601_to_minutes)

    comments_df.to_csv('/content/comments_preprocessed.csv', index=False, encoding='utf-8-sig')
    videos_df.to_csv('/content/videos_preprocessed.csv', index=False, encoding='utf-8-sig')

    print(f"Processed {len(comments_df)} comments and {len(videos_df)} videos")

if __name__ == "__main__":
    main()
# Out:
# Processed 93109 comments and 226 videos
